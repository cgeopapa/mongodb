# %% [markdown]
# # Εργασία mongodb
# ## Παπαδόπουλος Γεώργιος (AM: mpksa20010)
# ### Σύνδεση στη βάση δεδομένων

# %%
import pymongo
import pandas as pd
from pprint import pprint

client = pymongo.MongoClient("mongodb://localhost:27017")
db = client["imdb"]

def pretty(res):
    for doc in res:
        pprint(doc)

def prettyFast(res):
    i = 0
    for doc in res:
        pprint(doc)
        i = i + 1
        if i == 50:
            break

# %% [markdown]
# ### Ανέβασμα δεδομένων

# %%
# movies collection
collection = db["movies"]
collection.delete_many({})

csvfile = pd.read_csv('ml-latest/movies.csv' , quotechar='"', encoding='ISO-8859-1').to_dict('records')
for item in csvfile:
    item["genres"] = str(item["genres"]).split("|")
collection.insert_many(csvfile)
print("movies...done")
# Out:
# movies...done

# %% [markdown]
# ![movies](img/movies.png)

# %%
# tags collection
collection = db["tags"]
collection.delete_many({})

csvfile = pd.read_csv('ml-latest/tags.csv', quotechar='"', encoding='ISO-8859-1').to_dict('records')
collection.insert_many(csvfile)
print("tags...done")

# %% [markdown]
# ![tags](img/tags.png)

# %%
# genome-tags collection
collection = db["genome-tags"]
collection.delete_many({})

csvfile = pd.read_csv('ml-latest/genome-tags.csv', quotechar='"', encoding='ISO-8859-1').to_dict('records')
collection.insert_many(csvfile)
print("genome-tags...done")

# %% [markdown]
# ![genome-tags](img/genome-tags.png)

# %%
# genome-scores collection
collection = db["genome-scores"]
collection.delete_many({})

csvfile = pd.read_csv('ml-latest/genome-scores.csv', quotechar='"', encoding='ISO-8859-1').to_dict('records')
collection.insert_many(csvfile)
print("genome-scores...done")

# %% [markdown]
# ![genome-scores](img/genome-scores.png)

# %%
# ratings collection (commented out insert so it is not executed by accident, because this dataset is huge and takes about an hour to complete.
collection = db["ratings"]
# collection.delete_many({})

# csvfile = pd.read_csv('ml-latest/ratings.csv', quotechar='"', encoding='ISO-8859-1').to_dict('records')
# collection.insert_many(csvfile)
print("ratings...done")
# Out:
# collection ready
# Dict ready
# ratings...done

# %% [markdown]
# ![ratings](img/ratings.png)

# %% [markdown]
# ### Ερώτημα (a)
# Βρείτε τους χρήστες που έχουν ψηφίσει πάνω από 10 ταινίες

# %%
collection = db["ratings"]
result = collection.aggregate([
    {"$group": {"_id": "$movieId", "count": {"$sum": 1}}},
    {"$match": {"count": {"$gte": 10}}},
])
prettyFast(result)
# Out:
# {'_id': 162082, 'count': 723}
# {'_id': 6636, 'count': 992}
# {'_id': 468, 'count': 8115}
# {'_id': 4608, 'count': 149}
# {'_id': 56145, 'count': 3749}
# {'_id': 4910, 'count': 24}
# {'_id': 162246, 'count': 10}
# {'_id': 8759, 'count': 21}
# {'_id': 95738, 'count': 17}
# {'_id': 6217, 'count': 161}
# {'_id': 3056, 'count': 131}
# {'_id': 60461, 'count': 46}
# {'_id': 4499, 'count': 4757}
# {'_id': 82722, 'count': 31}
# {'_id': 112582, 'count': 287}
# {'_id': 3517, 'count': 24}
# {'_id': 133873, 'count': 31}
# {'_id': 100452, 'count': 13}
# {'_id': 133281, 'count': 115}
# {'_id': 3291, 'count': 26}
# {'_id': 2452, 'count': 104}
# {'_id': 58191, 'count': 308}
# {'_id': 8934, 'count': 192}
# {'_id': 2125, 'count': 7145}
# {'_id': 71619, 'count': 398}
# {'_id': 56485, 'count': 19}
# {'_id': 8532, 'count': 490}
# {'_id': 61269, 'count': 26}
# {'_id': 74156, 'count': 696}
# {'_id': 165503, 'count': 148}
# {'_id': 55373, 'count': 11}
# {'_id': 8131, 'count': 803}
# {'_id': 1877, 'count': 59}
# {'_id': 2177, 'count': 672}
# {'_id': 168286, 'count': 159}
# {'_id': 8774, 'count': 60}
# {'_id': 88785, 'count': 852}
# {'_id': 132555, 'count': 59}
# {'_id': 591, 'count': 36}
# {'_id': 60189, 'count': 25}
# {'_id': 88049, 'count': 10}
# {'_id': 6800, 'count': 945}
# {'_id': 26021, 'count': 51}
# {'_id': 1632, 'count': 183}
# {'_id': 65359, 'count': 85}
# {'_id': 1702, 'count': 5169}
# {'_id': 33821, 'count': 21}
# {'_id': 1080, 'count': 25221}
# {'_id': 61037, 'count': 76}
# {'_id': 115973, 'count': 58}

# %% [markdown]
# ### Ερώτημα (b)
# Βρείτε πόσα tags έχει η κάθε ταινία
#
# Το συγκεκριμένο query πήρε πάνω από μισή ώρα να εκτελεστεί. Δοκιμάστηκε, όμως, μέσα από το MongoDBCompass όπου επιστρέφονται μόνο 20 αποτελέσματα και έτσι έτρεξε πολύ γρηγορότερα.

# %%
collection = db["tags"]
result = collection.aggregate([
    {"$group": {"_id": "$movieId", "count": {"$sum": 1}}},
    {"$lookup": {
        "from": "movies",
        "localField": "_id",
        "foreignField": "movieId",
        "as": "movie"
    }},
    {"$replaceRoot":{
        "newRoot": {
            "$mergeObjects": [
                {"$arrayElemAt": ["$movie", 0]},
                "$$ROOT"
            ]
        }
    }},
    {"$project": {
        "count": 1,
        "title": 1,
        "_id": 0
    }}
])
prettyFast(result)

# %% [markdown]
# ### Ερώτημα (c)
# Βρείτε το µέσο rating ανά ταινία

# %%
collection = db["ratings"]
result = collection.aggregate([
    {"$group": {"_id": "$movieId", "averageRating": {"$avg": "$rating"}}},
        {"$lookup": {
        "from": "movies",
        "localField": "_id",
        "foreignField": "movieId",
        "as": "movie"
    }},
    {"$replaceRoot":{
        "newRoot": {
            "$mergeObjects": [
                {"$arrayElemAt": ["$movie", 0]},
                "$$ROOT"
            ]
        }
    }},
    {"$project": {
        "averageRating": 1,
        "title": 1,
        "_id": 0
    }}
])
prettyFast(result)
# Out:
# [{'_id': 137707, 'averageRating': 1.6666666666666667}, {'_id': 8265, 'averageRating': 2.264367816091954}, {'_id': 176439, 'averageRating': 2.0}, {'_id': 157162, 'averageRating': 4.0}, {'_id': 130734, 'averageRating': 2.0}, {'_id': 190295, 'averageRating': 4.5}, {'_id': 174873, 'averageRating': 2.3333333333333335}, {'_id': 6016, 'averageRating': 4.184896558122275}, {'_id': 105073, 'averageRating': 2.7083333333333335}, {'_id': 1620, 'averageRating': 3.3766221897276547}, {'_id': 164801, 'averageRating': 3.111111111111111}, {'_id': 134103, 'averageRating': 2.0}, {'_id': 5323, 'averageRating': 2.1045673076923075}, {'_id': 2389, 'averageRating': 2.8231052036199094}, {'_id': 3427, 'averageRating': 3.2676240208877285}, {'_id': 161177, 'averageRating': 2.7857142857142856}, {'_id': 130972, 'averageRating': 1.5}, {'_id': 86620, 'averageRating': 3.0}, {'_id': 173889, 'averageRating': 3.5}, {'_id': 138921, 'averageRating': 3.0}, {'_id': 179601, 'averageRating': 4.5}, {'_id': 103366, 'averageRating': 3.0705128205128207}, {'_id': 5354, 'averageRating': 3.4906542056074765}, {'_id': 193759, 'averageRating': 3.5}, {'_id': 4585, 'averageRating': 3.223}, {'_id': 94729, 'averageRating': 3.5}, {'_id': 2848, 'averageRating': 3.7454337899543377}, {'_id': 71376, 'averageRating': 2.8333333333333335}, {'_id': 6476, 'averageRating': 3.332512315270936}, {'_id': 170955, 'averageRating': 2.6}, {'_id': 1897, 'averageRating': 3.5576241134751774}, {'_id': 62208, 'averageRating': 3.6}, {'_id': 98956, 'averageRating': 3.66412213740458}, {'_id': 146054, 'averageRating': 2.8333333333333335}, {'_id': 158376, 'averageRating': 3.3333333333333335}, {'_id': 165809, 'averageRating': 3.0}, {'_id': 159721, 'averageRating': 2.730769230769231}, {'_id': 83359, 'averageRating': 3.438775510204082}, {'_id': 3109, 'averageRating': 3.122615803814714}, {'_id': 104731, 'averageRating': 2.5}, {'_id': 162042, 'averageRating': 3.25}, {'_id': 116503, 'averageRating': 3.093220338983051}, {'_id': 179485, 'averageRating': 5.0}, {'_id': 990, 'averageRating': 2.731707317073171}, {'_id': 27077, 'averageRating': 3.1666666666666665}, {'_id': 2248, 'averageRating': 3.8260787102892366}, {'_id': 4002, 'averageRating': 3.5837142857142856}, {'_id': 7275, 'averageRating': 3.1176470588235294}, {'_id': 182827, 'averageRating': 1.0}, {'_id': 168364, 'averageRating': 2.75}, {'_id': 64845, 'averageRating': 3.108695652173913}, {'_id': 115763, 'averageRating': 3.5}, {'_id': 179795, 'averageRating': 3.0714285714285716}, {'_id': 166790, 'averageRating': 3.5625}, {'_id': 98140, 'averageRating': 2.5833333333333335}, {'_id': 114895, 'averageRating': 5.0}, {'_id': 127090, 'averageRating': 2.2857142857142856}, {'_id': 112497, 'averageRating': 2.6475409836065573}, {'_id': 139062, 'averageRating': 1.9}, {'_id': 6338, 'averageRating': 2.701975476839237}, {'_id': 3726, 'averageRating': 3.5344530577088715}, {'_id': 26928, 'averageRating': 3.8048780487804876}, {'_id': 26163, 'averageRating': 3.8672131147540982}, {'_id': 55492, 'averageRating': 2.8933333333333335}, {'_id': 151609, 'averageRating': 1.7272727272727273}, {'_id': 79872, 'averageRating': 2.9545454545454546}, {'_id': 177277, 'averageRating': 4.0}, {'_id': 93520, 'averageRating': 2.6818181818181817}, {'_id': 73431, 'averageRating': 2.963302752293578}, {'_id': 110850, 'averageRating': 3.1666666666666665}, {'_id': 6253, 'averageRating': 2.5}, {'_id': 47254, 'averageRating': 3.2373493975903616}, {'_id': 74089, 'averageRating': 3.6}, {'_id': 66934, 'averageRating': 3.9590353833192924}, {'_id': 145994, 'averageRating': 4.111940298507463}, {'_id': 90108, 'averageRating': 2.625}, {'_id': 129399, 'averageRating': 3.5384615384615383}, {'_id': 122673, 'averageRating': 2.0}, {'_id': 6529, 'averageRating': 2.6578947368421053}, {'_id': 85070, 'averageRating': 2.5}, {'_id': 74434, 'averageRating': 3.53125}, {'_id': 114433, 'averageRating': 3.5}, {'_id': 120847, 'averageRating': 3.25}, {'_id': 66773, 'averageRating': 2.5}, {'_id': 128610, 'averageRating': 3.5833333333333335} ...

# %% [markdown]
# ### Ερώτημα (d)
# Βρείτε κατά µέσο όρο πόσα genres ανατίθενται σε κάποια ταινία

# %%
collection = db["movies"]
result = collection.aggregate([
    {"$addFields": {
       "count": {
           "$size": "$genres"
       }
    }},
    {"$group": {
        "_id": None,
        "averageGenreCount": {"$avg": "$count"}
    }},
    {"$project":{
        "_id": 0
    }}
])
prettyFast(result)
# Out:
# {'averageGenreCount': 1.8263451409687081}

# %% [markdown]
# ### Εισαγωγή indexes
# #### Ερώτημα (a)
# Σε αυτή την περίπτωση δεν μπορούμε να χρησιμοποιήσουμε τη δύναμη των indexes καθώς σύμφωνα με τα [docs](https://docs.mongodb.com/master/core/aggregation-pipeline/#pipeline-operators-and-indexes)
# της mongodb το `$group` stage μπορεί να χρησιμοποιήσει έναν index σε πολύ συγκεκριμένες περιπτώσεις που δεν ικανοποιούνται στην περίπτωσή μας.
# Ένω το `$match` stage μπορεί να χρησιμοιπήσει έναν index δυστυχώς πρόκειται για πεδίου που δημιουργείται από το `$group` και έτσι δεν υπάρχει δυνατότητα να δημιουργεί κάποιος index σε αυτό.

# %% [markdown]
# #### Ερώτημα (b)
# Η δημιουργία index σε αυτό το ερώτημα είναι σωτήρια. Όπως έχει σημειωθεί στο αρχικό ερώτημα (χωρίς index) η διάρκεια εκτέλεσής του ήταν υπερβολικά μεγάλη.
# Πλέον εκτελείται σε μερικά δευτερόλεπτα.

# %%
db["movies"].create_index([("movieId", 1)])
collection = db["tags"]
collection.create_index([("movieId", 1)])
# Out:
# 'movieId_1'

# %%
result = collection.aggregate([
    {"$group": {"_id": "$movieId", "count": {"$sum": 1}}},
    {"$lookup": {
        "from": "movies",
        "localField": "_id",
        "foreignField": "movieId",
        "as": "movie"
    }},
    {"$replaceRoot":{
        "newRoot": {
            "$mergeObjects": [
                {"$arrayElemAt": ["$movie", 0]},
                "$$ROOT"
            ]
        }
    }},
    {"$project": {
        "count": 1,
        "title": 1,
        "_id": 0
    }}
])
prettyFast(result)
# Out:
# {'count': 1, 'title': 'Seasons (2016)'}
# {'count': 1, 'title': 'Care Bears Movie, The (1985)'}
# {'count': 1, 'title': 'Gangsters, Guns and Zombies (2012)'}
# {'count': 1, 'title': "Isabella Rossellini's Green Porno Live (2015)"}
# {'count': 1, 'title': 'Kid Cannabis (2014)'}
# {'count': 1, 'title': 'Passing Strange (2009)'}
# {'count': 1, 'title': 'A Perfect Day (2015)'}
# {'count': 1, 'title': 'Crimson Petal and the White, The (2011)'}
# {'count': 1, 'title': 'Tusk (2014)'}
# {'count': 1, 'title': 'The Pharmacist (2003)'}
# {'count': 1, 'title': 'Hellbound (1994)'}
# {'count': 1,
#  'title': 'Three Kingdoms: Resurrection of the Dragon (Saam gwok dzi gin lung '
#           'se gap) (2008)'}
# {'count': 1, 'title': 'Tie That Binds, The (1995)'}
# {'count': 1, 'title': 'Viking, The (1928)'}
# {'count': 1, 'title': 'Epitaph (2007)'}
# {'count': 1, 'title': 'These Old Broads (2001)'}
# {'count': 1, 'title': 'With a Song in My Heart (1952)'}
# {'count': 1, 'title': 'Mr. Nobody (2009)'}
# {'count': 1, 'title': 'Magnificent Doll (1946)'}
# {'count': 1, 'title': 'The Lottery (1969)'}
# {'count': 1, 'title': 'Begotten (1990)'}
# {'count': 1, 'title': "One's Own Choice (1972)"}
# {'count': 1, 'title': 'The Legend of Hillbilly John (1974)'}
# {'count': 1, 'title': 'Low Fidelity (2011)'}
# {'count': 1, 'title': 'The Pass (2016)'}
# {'count': 1, 'title': "Puttin' on the Ritz (1930)"}
# {'count': 1, 'title': 'Duran Duran: Unstaged (2014)'}
# {'count': 1, 'title': 'Becoming Bulletproof (2014)'}
# {'count': 1, 'title': 'Tenacious D in The Pick of Destiny (2006)'}
# {'count': 1, 'title': 'Damned River (1989)'}
# {'count': 1, 'title': 'Adventures in Manhattan (1936)'}
# {'count': 1, 'title': 'Regression (2015)'}
# {'count': 1, 'title': 'Pet Sematary (1989)'}
# {'count': 1, 'title': 'The Sea and Poison (1986)'}
# {'count': 1, 'title': 'Conquest of Space (1955)'}
# {'count': 1, 'title': 'Vacation from Marriage (1945)'}
# {'count': 1, 'title': 'The Scorpion King 3: Battle for Redemption (2012)'}
# {'count': 1, 'title': 'Cheap Thrills (2013)'}
# {'count': 1,
#  'title': 'Warning for the Joensson Gang (Varning fÃ¶r JÃ¶nssonligan) (1981)'}
# {'count': 1, 'title': 'Born Equal (2006)'}
# {'count': 1, 'title': 'I am Jane Doe (2017)'}
# {'count': 1, 'title': 'Last Time I Saw Archie, The (1961)'}
# {'count': 1, 'title': "Father's Day Off (1953)"}
# {'count': 1, 'title': 'Iru Mugan (2016)'}
# {'count': 1, 'title': 'Batman/Superman Movie, The (1998)'}
# {'count': 1, 'title': 'Vamps (2012)'}
# {'count': 1, 'title': 'Justice (2017)'}
# {'count': 1, 'title': 'Slaughterhouse (1987)'}
# {'count': 1, 'title': 'Besotted (2001)'}
# {'count': 1, 'title': 'That Girl in Yellow Boots (2010)'}

# %% [markdown]
# #### Ερώτημα (c)
# Αντίστοιχα με το προηγούμενο ερώτημα και έδω η δημιουργία index ήταν σωτήρια

# %%
collection = db["ratings"]
collection.create_index([("movieId", 1)])
# Out:
# 'movieId_1'

# %%
result = collection.aggregate([
    {"$group": {"_id": "$movieId", "averageRating": {"$avg": "$rating"}}},
    {"$lookup": {
        "from": "movies",
        "localField": "_id",
        "foreignField": "movieId",
        "as": "movie"
    }},
    {"$replaceRoot":{
        "newRoot": {
            "$mergeObjects": [
                {"$arrayElemAt": ["$movie", 0]},
                "$$ROOT"
            ]
        }
    }},
    {"$project": {
        "averageRating": 1,
        "title": 1,
        "_id": 0
    }}
])
prettyFast(result)
# Out:
# {'averageRating': None, 'title': 'The Puzzle of the Red Orchid (1962)'}
# {'averageRating': None, 'title': 'Set It Off (1996)'}
# {'averageRating': None, 'title': 'Beauties of the Night (1952)'}
# {'averageRating': None,
#  'title': 'Distant Sky - Nick Cave & The Bad Seeds Live in Copenhagen (2018)'}
# {'averageRating': None, 'title': 'Black Horizon (2002)'}
# {'averageRating': None, 'title': '13 Hours (2016)'}
# {'averageRating': None, 'title': 'Condo Painting (2000)'}
# {'averageRating': None, 'title': 'Tears of Steel (2012)'}
# {'averageRating': None,
#  'title': 'Ugly, Dirty and Bad (Brutti sporchi e cattivi) (1976)'}
# {'averageRating': None, 'title': 'Toll of the Sea, The (1922)'}
# {'averageRating': None, 'title': 'December Boys (2007)'}
# {'averageRating': None, 'title': 'Left to Die (2012)'}
# {'averageRating': None, 'title': 'Stealing Paradise (2011)'}
# {'averageRating': None, 'title': 'Shortbus (2006)'}
# {'averageRating': None, 'title': 'Earth (1998)'}
# {'averageRating': None, 'title': 'Urban Legends: Bloody Mary (2005)'}
# {'averageRating': None, 'title': 'Pride and Prejudice (1995)'}
# {'averageRating': None, 'title': 'ATL (2006)'}
# {'averageRating': None, 'title': 'Ben-hur (2016)'}
# {'averageRating': None, 'title': 'The Zodiac Killer (1971)'}
# {'averageRating': None, 'title': 'Ballad of Little Jo, The (1993)'}
# {'averageRating': None, 'title': 'Un grand amour de Beethoven (1936)'}
# {'averageRating': None, 'title': 'The Pirates of Penzance (1980)'}
# {'averageRating': None, 'title': 'Desire (1946)'}
# {'averageRating': None, 'title': 'Joan Lui (1985)'}
# {'averageRating': None, 'title': 'Treasure of the Sierra Madre, The (1948)'}
# {'averageRating': None, 'title': 'Flying Down to Rio (1933)'}
# {'averageRating': None, 'title': 'More Kittens (1936)'}
# {'averageRating': None, 'title': 'The Dependent (1969)'}
# {'averageRating': None, 'title': 'Broadway Musicals: A Jewish Legacy (2013)'}
# {'averageRating': None, 'title': "I Can't Think Straight (2007)"}
# {'averageRating': None, 'title': 'Osmosis Jones (2001)'}
# {'averageRating': None, 'title': 'Sea Hawk, The (1940)'}
# {'averageRating': None, 'title': 'Winning London (2001)'}
# {'averageRating': None, 'title': 'Karma (1986)'}
# {'averageRating': None, 'title': 'Demon Hunter (2016)'}
# {'averageRating': None, 'title': 'Bloodbath at the House of Death (1984)'}
# {'averageRating': None, 'title': 'Hook (1991)'}
# {'averageRating': None, 'title': 'The Garden of Afflictions 2017'}
# {'averageRating': None, 'title': 'The Chateau Meroux (2011)'}
# {'averageRating': None, 'title': 'Cowboy (1958)'}
# {'averageRating': None, 'title': 'Christmas Town (2008)'}
# {'averageRating': None, 'title': 'First Person Plural (2000)'}
# {'averageRating': None, 'title': 'SebastiÃ¡n Marcelo Wainraich (2018)'}
# {'averageRating': None, 'title': 'The Odd Angry Shot (1979)'}
# {'averageRating': None, 'title': 'The Heat (2006)'}
# {'averageRating': None, 'title': 'Turbo: A Power Rangers Movie (1997)'}
# {'averageRating': None, 'title': 'Muppets, The (2011)'}
# {'averageRating': None,
#  'title': "Louis Theroux: America's Medicated Kids (2010)"}
# {'averageRating': None, 'title': 'Mean Guns (1997)'}

# %% [markdown]
# #### Ερώτημα (d)
# Και σε αυτό το ερώτημα λόγω τον εντολών που χρησιμοποιούνται δε γίνεται να χρησιμοποιηθούν indexes.
